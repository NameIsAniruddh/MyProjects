# %%
df = spark.read.format("csv").load("/Volumes/workspace/default/data_analysis/empdata.csv")
df.explain(True)
# Out:
# == Parsed Logical Plan ==
# Relation [_c0#11001,_c1#11002,_c2#11003,_c3#11004,_c4#11005] csv
#
# == Analyzed Logical Plan ==
# _c0: string, _c1: string, _c2: string, _c3: string, _c4: string
# Relation [_c0#11001,_c1#11002,_c2#11003,_c3#11004,_c4#11005] csv
#
# == Optimized Logical Plan ==
# Relation [_c0#11001,_c1#11002,_c2#11003,_c3#11004,_c4#11005] csv
#
# == Physical Plan ==
# FileScan csv [_c0#11001,_c1#11002,_c2#11003,_c3#11004,_c4#11005] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/data_analysis/empdata.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<_c0:string,_c1:string,_c2:string,_c3:string,_c4:string>

# %%
#in VMware to read directly from csv working fine
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import col
spark = SparkSession.builder.master("local[2]").appName("Spark DataFrames").getOrCreate()
sc = spark.sparkContext
rdd = sc.textFile("file:///home/hduser/empdata.txt")
# ['ArunKumar,chenanai,33,2016-09-20,10000', 'Lara,chennai,55,2016-09-21,10000', 'Vasudevan,banglore,43,2016-09-23,90000', 'Prakash,mumbai,29,2017-01-11,45000', 'Meena,chennai,31,2018-03-14,38000', 'Rohit,delhi,40,2015-07-19,52000', 'Sanjay,pune,36,2019-11-05,61000', 'Divya,hyderabad,27,2020-02-28,47000', 'Karthik,chennai,32,2014-05-22,75000', 'Anitha,coimbatore,30,2017-08-30,42000', 'Joseph,banglore,45,2013-12-17,88000', 'Nirmala,chennai,28,2021-04-09,39000', 'Suresh,mumbai,50,2012-10-01,99000', 'Harini,chennai,26,2022-06-15,36000', 'Manoj,delhi,38,2016-03-03,54000', 'Priya,chennai,34,2018-12-25,41000', 'Gokul,banglore,29,2019-09-10,58000', 'Swathi,hyderabad,33,2015-11-29,62000', 'Ramesh,chennai,41,2014-04-18,70000', 'Keerthi,pune,25,2023-01-12,35000']

rdd1=rdd.map(lambda x:x.split(","))
# [['ArunKumar', 'chenanai', '33', '2016-09-20', '10000'], ['Lara', 'chennai', '55', '2016-09-21', '10000'], ['Vasudevan', 'banglore', '43', '2016-09-23', '90000'], ['Prakash', 'mumbai', '29', '2017-01-11', '45000'], ['Meena', 'chennai', '31', '2018-03-14', '38000'], ['Rohit', 'delhi', '40', '2015-07-19', '52000'], ['Sanjay', 'pune', '36', '2019-11-05', '61000'], ['Divya', 'hyderabad', '27', '2020-02-28', '47000'], ['Karthik', 'chennai', '32', '2014-05-22', '75000'], ['Anitha', 'coimbatore', '30', '2017-08-30', '42000'], ['Joseph', 'banglore', '45', '2013-12-17', '88000'], ['Nirmala', 'chennai', '28', '2021-04-09', '39000'], ['Suresh', 'mumbai', '50', '2012-10-01', '99000'], ['Harini', 'chennai', '26', '2022-06-15', '36000'], ['Manoj', 'delhi', '38', '2016-03-03', '54000'], ['Priya', 'chennai', '34', '2018-12-25', '41000'], ['Gokul', 'banglore', '29', '2019-09-10', '58000'], ['Swathi', 'hyderabad', '33', '2015-11-29', '62000'], ['Ramesh', 'chennai', '41', '2014-04-18', '70000'], ['Keerthi', 'pune', '25', '2023-01-12', '35000']]

rdd2=rdd.map(lambda x:x.split(",")).map(lambda x:[x[0],x[1],x[2]])
# [['ArunKumar', 'chenanai', '33'], ['Lara', 'chennai', '55'], ['Vasudevan', 'banglore', '43'], ['Prakash', 'mumbai', '29'], ['Meena', 'chennai', '31'], ['Rohit', 'delhi', '40'], ['Sanjay', 'pune', '36'], ['Divya', 'hyderabad', '27'], ['Karthik', 'chennai', '32'], ['Anitha', 'coimbatore', '30'], ['Joseph', 'banglore', '45'], ['Nirmala', 'chennai', '28'], ['Suresh', 'mumbai', '50'], ['Harini', 'chennai', '26'], ['Manoj', 'delhi', '38'], ['Priya', 'chennai', '34'], ['Gokul', 'banglore', '29'], ['Swathi', 'hyderabad', '33'], ['Ramesh', 'chennai', '41'], ['Keerthi', 'pune', '25']]

collist=["first_name","last_name","age"]
df=rdd2.toDF(collist)

df.show()
# +----------+----------+---+
# |first_name| last_name|age|
# +----------+----------+---+
# | ArunKumar|  chenanai| 33|
# |      Lara|   chennai| 55|
# | Vasudevan|  banglore| 43|
# |   Prakash|    mumbai| 29|
# |     Meena|   chennai| 31|
# |     Rohit|     delhi| 40|
# |    Sanjay|      pune| 36|
# |     Divya| hyderabad| 27|
# |   Karthik|   chennai| 32|
# |    Anitha|coimbatore| 30|
# |    Joseph|  banglore| 45|
# |   Nirmala|   chennai| 28|
# |    Suresh|    mumbai| 50|
# |    Harini|   chennai| 26|
# |     Manoj|     delhi| 38|
# |     Priya|   chennai| 34|
# |     Gokul|  banglore| 29|
# |    Swathi| hyderabad| 33|
# |    Ramesh|   chennai| 41|
# |   Keerthi|      pune| 25|
# +----------+----------+---+

# %%
from pyspark.sql.functions import col

df = spark.read.format("csv").load("/Volumes/workspace/default/data_analysis/empdata.csv")
df1 = df.toDF("first_name", "last_name", "age", "doj", "salary")

df2=df1.filter(col("last_name")=="chennai")    
df2.show()

# +----------+---------+---+
# |first_name|last_name|age|
# +----------+---------+---+
# |      Lara|  chennai| 55|
# |     Meena|  chennai| 31|
# |   Karthik|  chennai| 32|
# |   Nirmala|  chennai| 28|
# |    Harini|  chennai| 26|
# |     Priya|  chennai| 34|
# |    Ramesh|  chennai| 41|
# +----------+---------+---+

df2=df1.where('last_name = "chennai"') #or df1=df.where("last_name = 'chennai'")
df2.show()

# +----------+---------+---+
# |first_name|last_name|age|
# +----------+---------+---+
# |      Lara|  chennai| 55|
# |     Meena|  chennai| 31|
# |   Karthik|  chennai| 32|
# |   Nirmala|  chennai| 28|
# |    Harini|  chennai| 26|
# |     Priya|  chennai| 34|
# |    Ramesh|  chennai| 41|
# +----------+---------+---+
# Out:
# +----------+---------+---+----------+------+
# |first_name|last_name|age|       doj|salary|
# +----------+---------+---+----------+------+
# | ArunKumar|  chennai| 33|20-09-2016| 10000|
# |      Lara|  chennai| 55|21-09-2016| 10000|
# |     Meena|  chennai| 31|14-03-2018| 38000|
# |   Karthik|  chennai| 32|22-05-2014| 75000|
# |   Nirmala|  chennai| 28|09-04-2021| 39000|
# |    Harini|  chennai| 26|15-06-2022| 36000|
# |     Priya|  chennai| 34|25-12-2018| 41000|
# |    Ramesh|  chennai| 41|18-04-2014| 70000|
# +----------+---------+---+----------+------+
#
# +----------+---------+---+----------+------+
# |first_name|last_name|age|       doj|salary|
# +----------+---------+---+----------+------+
# | ArunKumar|  chennai| 33|20-09-2016| 10000|
# |      Lara|  chennai| 55|21-09-2016| 10000|
# |     Meena|  chennai| 31|14-03-2018| 38000|
# |   Karthik|  chennai| 32|22-05-2014| 75000|
# |   Nirmala|  chennai| 28|09-04-2021| 39000|
# |    Harini|  chennai| 26|15-06-2022| 36000|
# ...

# %%
#in VMware to read directly from csv working fine
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import col
spark = SparkSession.builder.master("local[2]").appName("Spark DataFrames").getOrCreate()
sc = spark.sparkContext
rdd = sc.textFile("file:///home/hduser/empdata.txt")
# ['ArunKumar,chenanai,33,2016-09-20,10000', 'Lara,chennai,55,2016-09-21,10000', 'Vasudevan,banglore,43,2016-09-23,90000', 'Prakash,mumbai,29,2017-01-11,45000', 'Meena,chennai,31,2018-03-14,38000', 'Rohit,delhi,40,2015-07-19,52000', 'Sanjay,pune,36,2019-11-05,61000', 'Divya,hyderabad,27,2020-02-28,47000', 'Karthik,chennai,32,2014-05-22,75000', 'Anitha,coimbatore,30,2017-08-30,42000', 'Joseph,banglore,45,2013-12-17,88000', 'Nirmala,chennai,28,2021-04-09,39000', 'Suresh,mumbai,50,2012-10-01,99000', 'Harini,chennai,26,2022-06-15,36000', 'Manoj,delhi,38,2016-03-03,54000', 'Priya,chennai,34,2018-12-25,41000', 'Gokul,banglore,29,2019-09-10,58000', 'Swathi,hyderabad,33,2015-11-29,62000', 'Ramesh,chennai,41,2014-04-18,70000', 'Keerthi,pune,25,2023-01-12,35000']

rdd1=rdd.map(lambda x:x.split(","))
# [['ArunKumar', 'chenanai', '33', '2016-09-20', '10000'], ['Lara', 'chennai', '55', '2016-09-21', '10000'], ['Vasudevan', 'banglore', '43', '2016-09-23', '90000'], ['Prakash', 'mumbai', '29', '2017-01-11', '45000'], ['Meena', 'chennai', '31', '2018-03-14', '38000'], ['Rohit', 'delhi', '40', '2015-07-19', '52000'], ['Sanjay', 'pune', '36', '2019-11-05', '61000'], ['Divya', 'hyderabad', '27', '2020-02-28', '47000'], ['Karthik', 'chennai', '32', '2014-05-22', '75000'], ['Anitha', 'coimbatore', '30', '2017-08-30', '42000'], ['Joseph', 'banglore', '45', '2013-12-17', '88000'], ['Nirmala', 'chennai', '28', '2021-04-09', '39000'], ['Suresh', 'mumbai', '50', '2012-10-01', '99000'], ['Harini', 'chennai', '26', '2022-06-15', '36000'], ['Manoj', 'delhi', '38', '2016-03-03', '54000'], ['Priya', 'chennai', '34', '2018-12-25', '41000'], ['Gokul', 'banglore', '29', '2019-09-10', '58000'], ['Swathi', 'hyderabad', '33', '2015-11-29', '62000'], ['Ramesh', 'chennai', '41', '2014-04-18', '70000'], ['Keerthi', 'pune', '25', '2023-01-12', '35000']]

rdd2=rdd.map(lambda x:x.split(",")).map(lambda x:[x[0],x[1],x[2]])
# [['ArunKumar', 'chenanai', '33'], ['Lara', 'chennai', '55'], ['Vasudevan', 'banglore', '43'], ['Prakash', 'mumbai', '29'], ['Meena', 'chennai', '31'], ['Rohit', 'delhi', '40'], ['Sanjay', 'pune', '36'], ['Divya', 'hyderabad', '27'], ['Karthik', 'chennai', '32'], ['Anitha', 'coimbatore', '30'], ['Joseph', 'banglore', '45'], ['Nirmala', 'chennai', '28'], ['Suresh', 'mumbai', '50'], ['Harini', 'chennai', '26'], ['Manoj', 'delhi', '38'], ['Priya', 'chennai', '34'], ['Gokul', 'banglore', '29'], ['Swathi', 'hyderabad', '33'], ['Ramesh', 'chennai', '41'], ['Keerthi', 'pune', '25']]

collist=["first_name","last_name","age"]
df=spark.createDataFrame(rdd2, collist)

df.show()

# %%
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import col

list_dtls=[['ArunKumar', 'chenanai', '33'], ['Lara', 'chennai', '55'], ['Vasudevan', 'banglore', '43'], ['Prakash', 'mumbai', '29'], ['Meena', 'chennai', '31'], ['Rohit', 'delhi', '40'], ['Sanjay', 'pune', '36'], ['Divya', 'hyderabad', '27'], ['Karthik', 'chennai', '32'], ['Anitha', 'coimbatore', '30'], ['Joseph', 'banglore', '45'], ['Nirmala', 'chennai', '28'], ['Suresh', 'mumbai', '50'], ['Harini', 'chennai', '26'], ['Manoj', 'delhi', '38'], ['Priya', 'chennai', '34'], ['Gokul', 'banglore', '29'], ['Swathi', 'hyderabad', '33'], ['Ramesh', 'chennai', '41'], ['Keerthi', 'pune', '25']]

collist=["first_name","last_name","age"]
df=spark.createDataFrame(list_dtls, collist)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#in VMware to read directly from csv working fine
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import col
from pyspark.sql import Row
spark = SparkSession.builder.master("local[2]").appName("Spark DataFrames").getOrCreate()
sc = spark.sparkContext
rdd = sc.textFile("file:///home/hduser/empdata.txt")
# ['ArunKumar,chenanai,33,2016-09-20,10000', 'Lara,chennai,55,2016-09-21,10000', 'Vasudevan,banglore,43,2016-09-23,90000', 'Prakash,mumbai,29,2017-01-11,45000', 'Meena,chennai,31,2018-03-14,38000', 'Rohit,delhi,40,2015-07-19,52000', 'Sanjay,pune,36,2019-11-05,61000', 'Divya,hyderabad,27,2020-02-28,47000', 'Karthik,chennai,32,2014-05-22,75000', 'Anitha,coimbatore,30,2017-08-30,42000', 'Joseph,banglore,45,2013-12-17,88000', 'Nirmala,chennai,28,2021-04-09,39000', 'Suresh,mumbai,50,2012-10-01,99000', 'Harini,chennai,26,2022-06-15,36000', 'Manoj,delhi,38,2016-03-03,54000', 'Priya,chennai,34,2018-12-25,41000', 'Gokul,banglore,29,2019-09-10,58000', 'Swathi,hyderabad,33,2015-11-29,62000', 'Ramesh,chennai,41,2014-04-18,70000', 'Keerthi,pune,25,2023-01-12,35000']

rdd1=rdd.map(lambda x:x.split(","))
# [['ArunKumar', 'chenanai', '33', '2016-09-20', '10000'], ['Lara', 'chennai', '55', '2016-09-21', '10000'], ['Vasudevan', 'banglore', '43', '2016-09-23', '90000'], ['Prakash', 'mumbai', '29', '2017-01-11', '45000'], ['Meena', 'chennai', '31', '2018-03-14', '38000'], ['Rohit', 'delhi', '40', '2015-07-19', '52000'], ['Sanjay', 'pune', '36', '2019-11-05', '61000'], ['Divya', 'hyderabad', '27', '2020-02-28', '47000'], ['Karthik', 'chennai', '32', '2014-05-22', '75000'], ['Anitha', 'coimbatore', '30', '2017-08-30', '42000'], ['Joseph', 'banglore', '45', '2013-12-17', '88000'], ['Nirmala', 'chennai', '28', '2021-04-09', '39000'], ['Suresh', 'mumbai', '50', '2012-10-01', '99000'], ['Harini', 'chennai', '26', '2022-06-15', '36000'], ['Manoj', 'delhi', '38', '2016-03-03', '54000'], ['Priya', 'chennai', '34', '2018-12-25', '41000'], ['Gokul', 'banglore', '29', '2019-09-10', '58000'], ['Swathi', 'hyderabad', '33', '2015-11-29', '62000'], ['Ramesh', 'chennai', '41', '2014-04-18', '70000'], ['Keerthi', 'pune', '25', '2023-01-12', '35000']]

rdd2=rdd.map(lambda x:x.split(",")).map(lambda x:Row(first_name=x[0],last_name=x[1],age=x[2]))
# [['ArunKumar', 'chenanai', '33'], ['Lara', 'chennai', '55'], ['Vasudevan', 'banglore', '43'], ['Prakash', 'mumbai', '29'], ['Meena', 'chennai', '31'], ['Rohit', 'delhi', '40'], ['Sanjay', 'pune', '36'], ['Divya', 'hyderabad', '27'], ['Karthik', 'chennai', '32'], ['Anitha', 'coimbatore', '30'], ['Joseph', 'banglore', '45'], ['Nirmala', 'chennai', '28'], ['Suresh', 'mumbai', '50'], ['Harini', 'chennai', '26'], ['Manoj', 'delhi', '38'], ['Priya', 'chennai', '34'], ['Gokul', 'banglore', '29'], ['Swathi', 'hyderabad', '33'], ['Ramesh', 'chennai', '41'], ['Keerthi', 'pune', '25']]


df=rdd2.toDF()
df.show()

# %%
from pyspark.sql.session import SparkSession
#spark = SparkSession.builder.master("local[2]").appName("Spark DataFrames").getOrCreate()
df=spark.read.csv("/Volumes/workspace/default/data_analysis/empdata_header.csv",header=True,inferSchema=True,sep="|")
df.printSchema()
lst=df.columns
print(lst)
display(df)
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- JoinDate: date (nullable = true)
#  |-- Salary: integer (nullable = true)
#
# ['Name', 'City', 'Age', 'JoinDate', 'Salary']
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.session import SparkSession
#spark = SparkSession.builder.master("local[2]").appName("Spark DataFrames").getOrCreate()
df=spark.read.option("header","true").option("inferSchema","true").option("delimiter","|").format("csv").load("/Volumes/workspace/default/data_analysis/empdata_header.csv")
df.printSchema()
lst=df.columns
print(lst)
display(df)
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- JoinDate: date (nullable = true)
#  |-- Salary: integer (nullable = true)
#
# ['Name', 'City', 'Age', 'JoinDate', 'Salary']
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.session import SparkSession
#spark = SparkSession.builder.master("local[2]").appName("Spark DataFrames").getOrCreate()
df=spark.read.option("header","true").option("inferSchema","true").option("delimiter","|").csv("/Volumes/workspace/default/data_analysis/empdata_header.csv")
df1=df.toDF('FullName', 'Place', 'Age', 'DOJ', 'Sal')
df2=df1.withColumnRenamed("Sal","Salary").withColumnRenamed("test_col","test1_col")
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.session import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DateType
#spark = SparkSession.builder.master("local[2]").appName("Spark DataFrames").getOrCreate()
schema_csv = StructType([
    StructField('Name', StringType(), True),
    StructField('City', StringType(), True),
    StructField('Age', IntegerType(), True),
    StructField('JoinDate', StringType(), True),
    StructField('Salary', IntegerType(), True)
])
df=spark.read.option("header","true").option("delimiter","|").csv("/Volumes/workspace/default/data_analysis/empdata_header.csv",schema=schema_csv)
df.printSchema()
lst=df.columns
print(lst)
display(df)
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- JoinDate: string (nullable = true)
#  |-- Salary: integer (nullable = true)
#
# ['Name', 'City', 'Age', 'JoinDate', 'Salary']
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
