# %%
str = 'Jp is a good girl. She eats apple. Her bday is in June '
result = defaultdict(list)

for word in str.split():
    result[word[0]].append(word)
print(dict(result))
# Out:
# {'J': ['Jp', 'June'], 'i': ['is', 'is', 'in'], 'a': ['a', 'apple.'], 'g': ['good', 'girl.'], 'S': ['She'], 'e': ['eats'], 'H': ['Her'], 'b': ['bday']}

# %%
stage = int(input("What phase (1-4)?"))
print(stage)
# Out:
# What phase (1-4)? 5
# 5

# %%
salaries = [500000, 250000, 1000000, 1500000]
print(salaries)
print(type(salaries))
# Out:
# [500000, 250000, 1000000, 1500000]
# <class 'list'>

# %%
ani= ['Aniruddh',23,5000,True]
jp= ['Jp',25,5000,False]
employees=[ani,jp]
print(employees)
# Out:
# [['Aniruddh', 23, 5000, True], ['Jp', 25, 5000, False]]

# %%
ani= ('Aniruddh',23,5000,True)
jp= ('Jp',25,5000,False)
employees=[ani,jp]
print(employees)
# Out:
# [('Aniruddh', 23, 5000, True), ('Jp', 25, 5000, False)]

# %%
ani= {'Name':'Aniruddh','Age':23,'Sal':5000,'Status':True}
jp= {'Name':'Jp','Age':25,'Sal':5000,'Status':False}
employees=[ani,jp]
print(employees)
# Out:
# [{'Name': 'Aniruddh', 'Age': 23, 'Sal': 5000, 'Status': True}, {'Name': 'Jp', 'Age': 25, 'Sal': 5000, 'Status': False}]

# %%
freq={}
print(type(freq))
# Out:
# <class 'dict'>

# %%
salaries=[]
salaries.append(500000)
salaries.append(250000)
salaries.append(1000000)
salaries.append(1500000)
print(salaries)
# Out:
# [500000, 250000, 1000000, 1500000]

# %%
first_salary=salaries[0]
print(first_salary)
# Out:
# 250000

# %%
salaries.pop(0)
print(salaries)
# Out:
# [250000, 1000000, 1500000]

# %%
ani= {'Name':'Aniruddh','Age':23,'Sal':5000,'Status':True}
ani['hra_per']=20
ani['hra']=(ani['Sal']*ani['hra_per'])/100
print(ani)
# Out:
# {'Name': 'Aniruddh', 'Age': 23, 'Sal': 5000, 'Status': True, 'hra_per': 20, 'hra': 1000.0}

# %%
del ani['hra_per']
print(ani)
# Out:
# {'Name': 'Aniruddh', 'Age': 23, 'Sal': 5000, 'Status': True, 'hra': 1000.0}

# %%
name=ani['Name']
age=ani['Age']
sal=ani['Sal']
print(name,age,sal)
# Out:
# Aniruddh 23 5000

# %%
employees=[{'Name':'Aniruddh','Age':23,'Sal':5000,'Status':True},
              {'Name':'Jp','Age':25,'Sal':5000,'Status':False},
              {'Name':'Ravi','Age':27,'Sal':5000,'Status':True}]
for emp in employees:
    Sal=emp['Sal']
    Name=emp['Name']
    Age=emp['Age']
    Status=emp['Status']
    
    if age <25:
        print(Name,'is a young employee')
    else:
        print(Name,'is an old employee')
    if Status==True:
        print(Name,'is a married employee')
    else:
        print(Name,'is a unmarried employee')
    print('Salary of',Name,'is',Sal)
    print('hra of',Name,'is',(Sal*20)/100)
    print('------------------')
# Out:
# Aniruddh is a young employee
# Aniruddh is a married employee
# Salary of Aniruddh is 5000
# hra of Aniruddh is 1000.0
# ------------------
# Jp is a young employee
# Jp is a unmarried employee
# Salary of Jp is 5000
# hra of Jp is 1000.0
# ------------------
# Ravi is a young employee
# Ravi is a married employee
# Salary of Ravi is 5000
# hra of Ravi is 1000.0
# ------------------

# %%
ages=[10,26,2,5,18,20,13,7,8,14]
print('Max of first 2 ages')
print(max(ages[:2]))
print('Max of last 2 ages')
print(max(ages[-2:]))
print('Max of ages between 2 and 5')
print(max(ages[2:5]))
print(f'Max of ages between {ages[3]} and {ages[6]} is {max(ages[3:6])}')
print('Max of ages between %d and %d is %d' % (ages[3],ages[6],max(ages[3:6])))
# Out:
# Max of first 2 ages
# 26
# Max of last 2 ages
# 14
# Max of ages between 2 and 5
# 18
# Max of ages between 5 and 13 is 20
# Max of ages between 5 and 13 is 20

# %%
ages=[10,26,2,5,18,20,13,7,8,14]
print('Max of first 2 ages')
print(max(ages[:2]))
print('Max of last 2 ages')
print(max(ages[-2:]))
print('Max of ages between 2 and 5')
print(max(ages[2:5]))
print(f'Max of ages between {ages[3]} and {ages[6]} is {max(ages[3:6])}')
print('Max of ages between %d and %d is %d' % (ages[3],ages[6],max(ages[3:6])))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
#   File <command-6493480910007698>, line 9
#     print('Max of ages between %d and %d is %d',%(ages[3],ages[6],max(ages[3:6])))
#                                                 ^
# SyntaxError: invalid syntax

# %%
ages=[10,26,2,5,18,20,13,7,8,14]
print('Max of first 2 ages')
print(max(ages[:2]))
print('Max of last 2 ages')
print(max(ages[-2:]))
print('Max of ages between 2 and 5')
print(max(ages[2:5]))
print(f'Max of ages between {ages[3]} and {ages[6]} is {max(ages[3:6])}')
print('Max of ages between %d and %d is %d' % (ages[3],ages[6],max(ages[3:6])))
# Out:
# Max of first 2 ages
# 26
# Max of last 2 ages
# 14
# Max of ages between 2 and 5
# 18
# Max of ages between 5 and 13 is 20
# Max of ages between 5 and 13 is 20

# %%
for i in range(10):
    print(ages[i],end=' ')

print('\n')
for age in ages:
    print(age,end=', ')
# Out:
# 10 26 2 5 18 20 13 7 8 14
#
# 10, 26, 2, 5, 18, 20, 13, 7, 8, 14,

# %%
s=0
for age in ages:
    s+=age
avg=s//len(ages)
print(f'Sum is {s} and average is {avg}')
# Out:
# Sum is 123 and average is 12

# %%
above_teen=0
others=0

for age in ages:
    if age >19:
        above_teen+=1
    else:
        others+=1
print(f'There are {above_teen} above teens and {others} are teens')
# Out:
# There are 2 above teens and 8 are teens

# %%
print(f'Before ages increment {ages}')
for i in range(10):
    ages[i]+=1
print(f'After ages increment {ages}')
# Out:
# Before ages increment [10, 26, 2, 5, 18, 20, 13, 7, 8, 14]
# After ages increment [11, 27, 3, 6, 19, 21, 14, 8, 9, 15]

# %%
age11=23
ages.append(age11)
print(f'After appending age11 {ages}')
# Out:
# After appending age11 [11, 27, 3, 6, 19, 21, 14, 8, 9, 15, 23]

# %%
employees=[]
employees.append({'name':'Jaiswal','age': 22})

employees.append({'name': 'Suryavansy','age':14})

employees.append({'name':'Sreyes', 'age':28})

employees.append({'name':'Archer', 'age':30})

print(employees)

max_aged=employees[0] 

for emp in employees:
    emp['age'] += 1

print(employees)
# Out:
# [{'name': 'Jaiswal', 'age': 22}, {'name': 'Suryavansy', 'age': 14}, {'name': 'Sreyes', 'age': 28}, {'name': 'Archer', 'age': 30}]
# [{'name': 'Jaiswal', 'age': 23}, {'name': 'Suryavansy', 'age': 15}, {'name': 'Sreyes', 'age': 29}, {'name': 'Archer', 'age': 31}]

# %%
import csv 
with open('update_employees1.csv', 'w', newline="") as out:

    fieldnames = ['name','age']
    writer = csv.DictWriter(out,fieldnames=fieldnames)

    writer.writeheader()

    for emp in employees:

        writer.writerow(emp)
